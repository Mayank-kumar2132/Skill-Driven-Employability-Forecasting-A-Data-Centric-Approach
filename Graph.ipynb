# %%
pip install pytesseract
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pytesseract in c:\users\mayank kumar\anaconda3\lib\site-packages (0.3.10)
# ...

# %%
pip install pillow

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
image_path = r"C:\Users\MAYANK KUMAR\OneDrive\Desktop\images.jpg"
text = pytesseract.image_to_string(image_path)
print(text)
# Out:
# Hamne to aik sakhs par
# chahat khatam kardi
# ‘Ab mohabbat kise kahte hain
# hamen maloom nahin
#
# ew. poeteytadka com

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = {
    'Models': ['SVM', 'Decision Tree', 'Logistic Regression', 'Naïve Bayes', 'Random Forest', 'AdaBoost', 'Gradient Boosting Classifier'],
    'Accuracy': [0.54, 0.7, 0.7, 0.54, 0.55, 0.55, 0.6],
    'Precision Score': [0.54, 0.72, 0.68, 0.54, 0.54, 0.54, 0.58],
    'Recall Score': [1, 0.71, 0.83, 1, 0.99, 0.99, 0.93],
    'F1 Score': [0.7, 0.72, 0.75, 0.7, 0.7, 0.7, 0.71]
}
df = pd.DataFrame(data)
sns.set_style("whitegrid")
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
sns.barplot(x='Models', y='Accuracy', data=df, ax=axes[0, 0])
axes[0, 0].set_title('Accuracy')
sns.barplot(x='Models', y='Precision Score', data=df, ax=axes[0, 1])
axes[0, 1].set_title('Precision Score')
sns.barplot(x='Models', y='Recall Score', data=df, ax=axes[1, 0])
axes[1, 0].set_title('Recall Score')
sns.barplot(x='Models', y='F1 Score', data=df, ax=axes[1, 1])
axes[1, 1].set_title('F1 Score')
for ax in axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Create a DataFrame with the provided data
data = {
    'Models': ['SVM', 'Decision Tree', 'Logistic Regression', 'Naïve Bayes', 'Random Forest', 'AdaBoost', 'Gradient Boosting Classifier'],
    'Accuracy': [0.54, 0.7, 0.7, 0.54, 0.55, 0.55, 0.6],
    'Precision Score': [0.54, 0.72, 0.68, 0.54, 0.54, 0.54, 0.58],
    'Recall Score': [1, 0.71, 0.83, 1, 0.99, 0.99, 0.93],
    'F1 Score': [0.7, 0.72, 0.75, 0.7, 0.7, 0.7, 0.71]
}
df = pd.DataFrame(data)
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df.drop('Models', axis=1), dashes=False)
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Performance Metrics for Different Models')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Metrics', loc='lower right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = {
    'Models': ['SVM', 'Decision Tree', 'Logistic Regression', 'Naïve Bayes', 'Random Forest', 'AdaBoost', 'Gradient Boosting Classifier'],
    'Accuracy': [0.54, 0.7, 0.7, 0.54, 0.55, 0.55, 0.6],
    'Precision Score': [0.54, 0.72, 0.68, 0.54, 0.54, 0.54, 0.58],
    'Recall Score': [1, 0.71, 0.83, 1, 0.99, 0.99, 0.93],
    'F1 Score': [0.7, 0.72, 0.75, 0.7, 0.7, 0.7, 0.71]
}
df = pd.DataFrame(data)
sns.set_style("whitegrid")
plt.figure(figsize=(12, 6))
df_melted = df.melt(id_vars='Models', var_name='Metric', value_name='Value')
sns.barplot(data=df_melted, x='Models', y='Value', hue='Metric')
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Performance Metrics for Different Models')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Metrics', loc='upper right')
plt.tight_layout()
plt.show()
